# %%
# Python bytecode
*.pyc
__pycache__/

# Virtual environment
venv/
.env

# Database
db.sqlite3

# Static and media files
staticfiles/
mediafiles/

# Logs
*.log

# IDE
.idea/

# Misc
*.swp
.DS_Store
